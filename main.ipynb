# %%
import pip
pip.main(['install','seaborn'])
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set_style('darkgrid')

data=pd.read_csv('./dataset.csv')
# Out:
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# Requirement already satisfied: seaborn in /home/godotgodo/Desktop/attention_analysis/venv/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/godotgodo/Desktop/attention_analysis/venv/lib/python3.12/site-packages (from seaborn) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in /home/godotgodo/Desktop/attention_analysis/venv/lib/python3.12/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/godotgodo/Desktop/attention_analysis/venv/lib/python3.12/site-packages (from seaborn) (3.9.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/godotgodo/Desktop/attention_analysis/venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/godotgodo/Desktop/attention_analysis/venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/godotgodo/Desktop/attention_analysis/venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/godotgodo/Desktop/attention_analysis/venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/godotgodo/Desktop/attention_analysis/venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /home/godotgodo/Desktop/attention_analysis/venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/godotgodo/Desktop/attention_analysis/venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/godotgodo/Desktop/attention_analysis/venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/godotgodo/Desktop/attention_analysis/venv/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/godotgodo/Desktop/attention_analysis/venv/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in /home/godotgodo/Desktop/attention_analysis/venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'timestamp', 'sensor_00', 'sensor_01', 'sensor_02',
#        'sensor_03', 'sensor_04', 'sensor_05', 'sensor_06', 'sensor_07',
#        'sensor_08', 'sensor_09', 'sensor_10', 'sensor_11', 'sensor_12',
#        'sensor_13', 'sensor_14', 'sensor_15', 'sensor_16', 'sensor_17',
#        'sensor_18', 'sensor_19', 'sensor_20', 'sensor_21', 'sensor_22',
#        'sensor_23', 'sensor_24', 'sensor_25', 'sensor_26', 'sensor_27',
#        'sensor_28', 'sensor_29', 'sensor_30', 'sensor_31', 'sensor_32',
#        'sensor_33', 'sensor_34', 'sensor_35', 'sensor_36', 'sensor_37',
#        'sensor_38', 'sensor_39', 'sensor_40', 'sensor_41', 'sensor_42',
#        'sensor_43', 'sensor_44', 'sensor_45', 'sensor_46', 'sensor_47',
#        'sensor_48', 'sensor_49', 'sensor_50', 'sensor_51', 'machine_status'],
#       dtype='object')

# %%
data.describe().transpose()
# Out:
#                count           mean           std        min           25%  \
# Unnamed: 0  220320.0  110159.500000  63601.049991   0.000000  55079.750000
# sensor_00   210112.0       2.372221      0.412227   0.000000      2.438831
# sensor_01   219951.0      47.591611      3.296666   0.000000     46.310760
# sensor_02   220301.0      50.867392      3.666820  33.159720     50.390620
# sensor_03   220301.0      43.752481      2.418887  31.640620     42.838539
# sensor_04   220301.0     590.673936    144.023912   2.798032    626.620400
# sensor_05   220301.0      73.396414     17.298247   0.000000     69.976260
# sensor_06   215522.0      13.501537      2.163736   0.014468     13.346350
# sensor_07   214869.0      15.843152      2.201155   0.000000     15.907120
# sensor_08   215213.0      15.200721      2.037390   0.028935     15.183740
# sensor_09   215725.0      14.799210      2.091963   0.000000     15.053530
# sensor_10   220301.0      41.470339     12.093519   0.000000     40.705260
# sensor_11   220301.0      41.918319     13.056425   0.000000     38.856420
# sensor_12   220301.0      29.136975     10.113935   0.000000     28.686810
# sensor_13   220301.0       7.078858      6.901755   0.000000      1.538516
# sensor_14   220299.0     376.860041    113.206382  32.409550    418.103250
# sensor_15        0.0            NaN           NaN        NaN           NaN
# sensor_16   220289.0     416.472892    126.072642   0.000000    459.453400
# sensor_17   220274.0     421.127517    129.156175   0.000000    454.138825
# sensor_18   220274.0       2.303785      0.765883   0.000000      2.447542
# sensor_19   220304.0     590.829775    199.345820   0.000000    662.768975
# sensor_20   220304.0     360.805165    101.974118   0.000000    398.021500
# sensor_21   220304.0     796.225942    226.679317  95.527660    875.464400
# sensor_22   220279.0     459.792815    154.528337   0.000000    478.962600
# sensor_23   220304.0     922.609264    291.835280   0.000000    950.922400
# sensor_24   220304.0     556.235397    182.297979   0.000000    601.151050
# sensor_25   220284.0     649.144799    220.865166   0.000000    693.957800
# sensor_26   220300.0     786.411781    246.663608  43.154790    790.489575
# sensor_27   220304.0     501.506589    169.823173   0.000000    448.297950
# sensor_28   220304.0     851.690339    313.074032   4.319347    782.682625
# sensor_29   220248.0     576.195305    225.764091   0.636574    518.947225
# sensor_30   220059.0     614.596442    195.726872   0.000000    627.777800
# sensor_31   220304.0     863.323100    283.544760  23.958330    839.062400
# sensor_32   220252.0     804.283915    260.602361   0.240716    760.607475
# sensor_33   220304.0     486.405980    150.751836   6.460602    489.761075
# sensor_34   220304.0     234.971776     88.376065  54.882370    172.486300
# sensor_35   220304.0     427.129817    141.772519   0.000000    353.176625
# sensor_36   220304.0     593.033876    289.385511   2.260970    288.547575
# sensor_37   220304.0      60.787360     37.604883   0.000000     28.799220
# sensor_38   220293.0      49.655946     10.540397  24.479166     45.572910
# sensor_39   220293.0      36.610444     15.613723  19.270830     32.552080
# sensor_40   220293.0      68.844530     21.371139  23.437500     57.812500
# sensor_41   220293.0      35.365126      7.898665  20.833330     32.552080
# sensor_42   220293.0      35.453455     10.259521  22.135416     32.812500
# sensor_43   220293.0      43.879591     11.044404  24.479166     39.583330
# sensor_44   220293.0      42.656877     11.576355  25.752316     36.747684
# sensor_45   220293.0      43.094984     12.837520  26.331018     36.747684
# sensor_46   220293.0      48.018585     15.641284  26.331018     40.509258
# sensor_47   220293.0      44.340903     10.442437  27.199070     39.062500
# sensor_48   220293.0     150.889044     82.244957  26.331018     83.912030
# sensor_49   220293.0      57.119968     19.143598  26.620370     47.743060
# sensor_50   143303.0     183.049260     65.258650  27.488426    167.534700
# sensor_51   204937.0     202.699667    109.588607  27.777779    179.108800
#
#                       50%            75%            max
# Unnamed: 0  110159.500000  165239.250000  220319.000000
# sensor_00        2.456539       2.499826       2.549016
# sensor_01       48.133678      49.479160      56.727430
# sensor_02       51.649300      52.777770      56.032990
# sensor_03       44.227428      45.312500      48.220490
# sensor_04      632.638916     637.615723     800.000000
# sensor_05       75.576790      80.912150      99.999880
# sensor_06       13.642940      14.539930      22.251160
# sensor_07       16.167530      16.427950      23.596640
# sensor_08       15.494790      15.697340      24.348960
# sensor_09       15.082470      15.118630      25.000000
# sensor_10       44.291340      47.463760      76.106860
# sensor_11       45.363140      49.656540      60.000000
# sensor_12       32.515830      34.939730      45.000000
# sensor_13        2.929809      12.859520      31.187550
# sensor_14      420.106200     420.997100     500.000000
# sensor_15             NaN            NaN            NaN
# sensor_16      462.856100     464.302700     739.741500
# sensor_17      462.020250     466.857075     599.999939
# sensor_18        2.533704       2.587682       4.873250
# sensor_19      665.672400     667.146700     878.917900
# sensor_20      399.367000     400.088400     448.907900
# sensor_21      879.697600     882.129900    1107.526000
# sensor_22      531.855900     534.254850     594.061100
# sensor_23      981.925000    1090.808000    1227.564000
# sensor_24      625.873500     628.607725    1000.000000
# sensor_25      740.203500     750.357125     839.575000
# sensor_26      861.869600     919.104775    1214.420000
# sensor_27      494.468450     536.274550    2000.000000
# sensor_28      967.279850    1043.976500    1841.146000
# sensor_29      564.872500     744.021475    1466.281000
# sensor_30      668.981400     697.222200    1600.000000
# sensor_31      917.708300     981.249900    1800.000000
# sensor_32      878.850750     943.877625    1839.211000
# sensor_33      512.271750     555.163225    1578.600000
# sensor_34      226.356050     316.844950     425.549800
# sensor_35      473.349350     528.891025     694.479126
# sensor_36      709.668050     837.333025     984.060700
# sensor_37       64.295485      90.821928     174.901200
# sensor_38       49.479160      53.645830     417.708300
# sensor_39       35.416660      39.062500     547.916600
# sensor_40       66.406250      77.864580     512.760400
# sensor_41       34.895832      37.760410     420.312500
# sensor_42       35.156250      36.979164     374.218800
# sensor_43       42.968750      46.614580     408.593700
# sensor_44       40.509260      45.138890    1000.000000
# sensor_45       40.219910      44.849540     320.312500
# sensor_46       44.849540      51.215280     370.370400
# sensor_47       42.534720      46.585650     303.530100
# sensor_48      138.020800     208.333300     561.632000
# sensor_49       52.662040      60.763890     464.409700
# sensor_50      193.865700     219.907400    1000.000000
# sensor_51      197.338000     216.724500    1000.000000

# %%
data.isnull().sum()
# Out:
# Unnamed: 0             0
# timestamp              0
# sensor_00          10208
# sensor_01            369
# sensor_02             19
# sensor_03             19
# sensor_04             19
# sensor_05             19
# sensor_06           4798
# sensor_07           5451
# sensor_08           5107
# sensor_09           4595
# sensor_10             19
# sensor_11             19
# sensor_12             19
# sensor_13             19
# sensor_14             21
# sensor_15         220320
# sensor_16             31
# sensor_17             46
# sensor_18             46
# sensor_19             16
# sensor_20             16
# sensor_21             16
# sensor_22             41
# sensor_23             16
# sensor_24             16
# sensor_25             36
# sensor_26             20
# sensor_27             16
# sensor_28             16
# sensor_29             72
# sensor_30            261
# sensor_31             16
# sensor_32             68
# sensor_33             16
# sensor_34             16
# sensor_35             16
# sensor_36             16
# sensor_37             16
# sensor_38             27
# sensor_39             27
# sensor_40             27
# sensor_41             27
# sensor_42             27
# sensor_43             27
# sensor_44             27
# sensor_45             27
# sensor_46             27
# sensor_47             27
# sensor_48             27
# sensor_49             27
# sensor_50          77017
# sensor_51          15383
# machine_status         0
# dtype: int64

# %%
data.drop(['Unnamed: 0', 'timestamp','sensor_00','sensor_15','sensor_50','sensor_51'],axis=1, inplace=True)

# %%
data.plot(subplots =True, sharex = True, figsize = (20,50))
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#       dtype=object)

# %%
data['machine_status'].value_counts()
# Out:
# machine_status
# NORMAL        205836
# RECOVERING     14477
# BROKEN             7
# Name: count, dtype: int64

# %%
conditions = [(data['machine_status'] =='NORMAL'), (data['machine_status'] =='BROKEN'), (data['machine_status'] =='RECOVERING')]
choices = [1, 0, 0.5]
data['Operation'] = np.select(conditions, choices, default=0)

# %%
data.plot(subplots =True, sharex = True, figsize = (20,50))
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >,
#        <Axes: >], dtype=object)

# %%
data.columns
# Out:
# Index(['sensor_01', 'sensor_02', 'sensor_03', 'sensor_04', 'sensor_05',
#        'sensor_06', 'sensor_07', 'sensor_08', 'sensor_09', 'sensor_10',
#        'sensor_11', 'sensor_12', 'sensor_13', 'sensor_14', 'sensor_16',
#        'sensor_17', 'sensor_18', 'sensor_19', 'sensor_20', 'sensor_21',
#        'sensor_22', 'sensor_23', 'sensor_24', 'sensor_25', 'sensor_26',
#        'sensor_27', 'sensor_28', 'sensor_29', 'sensor_30', 'sensor_31',
#        'sensor_32', 'sensor_33', 'sensor_34', 'sensor_35', 'sensor_36',
#        'sensor_37', 'sensor_38', 'sensor_39', 'sensor_40', 'sensor_41',
#        'sensor_42', 'sensor_43', 'sensor_44', 'sensor_45', 'sensor_46',
#        'sensor_47', 'sensor_48', 'sensor_49', 'machine_status', 'Operation'],
#       dtype='object')

# %%
df0 = pd.DataFrame(data, columns=['Operation','sensor_04', 'sensor_06', 'sensor_07', 'sensor_08', 'sensor_09'])

# %%
df1 = pd.DataFrame(data, columns=['Operation','sensor_01', 'sensor_04', 'sensor_10', 'sensor_14', 'sensor_19', 'sensor_25'])

# %%
df2 = pd.DataFrame(data, columns = ['Operation','sensor_02', 'sensor_05', 'sensor_11', 'sensor_16', 'sensor_20', 'sensor_26'])

# %%
df3 = pd.DataFrame(data, columns = ['Operation','sensor_03', 'sensor_06', 'sensor_12', 'sensor_17', 'sensor_21', 'sensor_28'])

# %%
df0.plot(subplots =True, sharex = True, figsize = (20,20))
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#       dtype=object)

# %%
df = df0
df.shape
# Out:
# (220320, 6)

# %%
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]
    dff = pd.DataFrame(data)
    cols, names = list(), list()
    for i in range(n_in, 0, -1):
        cols.append(dff.shift(-i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    for i in range(0, n_out):
        cols.append(dff.shift(-i))
        if i==0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1)) for j in range(n_vars)]        
        agg = pd.concat(cols, axis=1)
        agg.columns = names
        if dropnan:
            agg.dropna(inplace=True)
        return agg

# %%
from sklearn.preprocessing import MinMaxScaler

values = df.values
scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values)
reframed = series_to_supervised(scaled, 1, 1)
r = list(range(df.shape[1]+1, 2*df.shape[1]))
reframed.drop(reframed.columns[r], axis=1, inplace=True)
reframed.head()


values = reframed.values
n_train_time = 50000
train = values[:n_train_time, :]
test = values[n_train_time:, :]
train_x, train_y = train[:, :-1], train[:, -1]
test_x, test_y = test[:, :-1], test[:, -1]
train_x = train_x.reshape((train_x.shape[0], 1, train_x.shape[1]))
test_x = test_x.reshape((test_x.shape[0], 1, test_x.shape[1]))

# %%
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Dense
from sklearn.metrics import mean_squared_error,r2_score
import matplotlib.pyplot as plt
import numpy as np

model = Sequential()
model.add(LSTM(100, input_shape=(train_x.shape[1], train_x.shape[2])))
model.add(Dropout(0.2))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# Network fitting
history = model.fit(train_x, train_y, epochs=50, batch_size=70, validation_data=(test_x, test_y), verbose=2, shuffle=False)

# Loss history plot
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()

size = df.shape[1]

yhat = model.predict(test_x)
test_x = test_x.reshape((test_x.shape[0], size))

inv_yhat = np.concatenate((yhat, test_x[:, 1-size:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]

test_y = test_y.reshape((len(test_y), 1))
inv_y = np.concatenate((test_y, test_x[:, 1-size:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]

rmse = np.sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# 2024-12-20 00:10:35.109627: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-20 00:10:35.113675: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-20 00:10:35.124724: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1734642635.144289  168381 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1734642635.149800  168381 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-20 00:10:35.168966: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-20 00:10:37.217662: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# /home/godotgodo/Desktop/attention_analysis/venv/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 715/715 - 7s - 10ms/step - loss: 0.0321 - val_loss: 0.0016
# Epoch 2/50
# 715/715 - 6s - 8ms/step - loss: 0.0052 - val_loss: 0.0013
# Epoch 3/50
# 715/715 - 6s - 8ms/step - loss: 0.0046 - val_loss: 0.0012
# Epoch 4/50
# 715/715 - 6s - 8ms/step - loss: 0.0043 - val_loss: 0.0012
# Epoch 5/50
# 715/715 - 6s - 8ms/step - loss: 0.0042 - val_loss: 0.0012
# Epoch 6/50
# 715/715 - 6s - 8ms/step - loss: 0.0041 - val_loss: 0.0012
# Epoch 7/50
# 715/715 - 6s - 8ms/step - loss: 0.0039 - val_loss: 0.0011
# Epoch 8/50
# 715/715 - 6s - 8ms/step - loss: 0.0037 - val_loss: 0.0011
# Epoch 9/50
# 715/715 - 6s - 8ms/step - loss: 0.0035 - val_loss: 0.0010
# Epoch 10/50
# 715/715 - 6s - 8ms/step - loss: 0.0032 - val_loss: 9.6068e-04
# Epoch 11/50
# 715/715 - 6s - 8ms/step - loss: 0.0029 - val_loss: 9.0280e-04
# Epoch 12/50
# 715/715 - 6s - 8ms/step - loss: 0.0027 - val_loss: 8.4927e-04
# Epoch 13/50
# 715/715 - 6s - 8ms/step - loss: 0.0024 - val_loss: 7.8079e-04
# Epoch 14/50
# 715/715 - 6s - 8ms/step - loss: 0.0022 - val_loss: 7.1342e-04
# Epoch 15/50
# 715/715 - 6s - 8ms/step - loss: 0.0019 - val_loss: 6.7608e-04
# Epoch 16/50
# 715/715 - 6s - 8ms/step - loss: 0.0017 - val_loss: 6.2577e-04
# Epoch 17/50
# 715/715 - 6s - 8ms/step - loss: 0.0015 - val_loss: 5.9505e-04
# Epoch 18/50
# 715/715 - 6s - 8ms/step - loss: 0.0013 - val_loss: 5.5193e-04
# Epoch 19/50
# 715/715 - 6s - 8ms/step - loss: 0.0012 - val_loss: 4.8200e-04
# Epoch 20/50
# 715/715 - 6s - 8ms/step - loss: 0.0010 - val_loss: 4.7004e-04
# Epoch 21/50
# 715/715 - 6s - 8ms/step - loss: 8.8155e-04 - val_loss: 4.2933e-04
# Epoch 22/50
# 715/715 - 6s - 8ms/step - loss: 7.7229e-04 - val_loss: 3.8940e-04
# Epoch 23/50
# 715/715 - 6s - 8ms/step - loss: 7.0520e-04 - val_loss: 3.8434e-04
# Epoch 24/50
# 715/715 - 6s - 8ms/step - loss: 6.3934e-04 - val_loss: 3.6936e-04
# Epoch 25/50
# 715/715 - 6s - 8ms/step - loss: 5.8803e-04 - val_loss: 3.7000e-04
# Epoch 26/50
# 715/715 - 6s - 8ms/step - loss: 5.8522e-04 - val_loss: 4.0577e-04
# Epoch 27/50
# 715/715 - 6s - 8ms/step - loss: 5.3743e-04 - val_loss: 3.8240e-04
# Epoch 28/50
# 715/715 - 6s - 8ms/step - loss: 4.7680e-04 - val_loss: 3.1647e-04
# Epoch 29/50
# 715/715 - 6s - 8ms/step - loss: 4.1165e-04 - val_loss: 2.7995e-04
# Epoch 30/50
# 715/715 - 6s - 8ms/step - loss: 3.8837e-04 - val_loss: 3.1932e-04
# Epoch 31/50
# 715/715 - 6s - 8ms/step - loss: 4.0487e-04 - val_loss: 4.5121e-04
# Epoch 32/50
# 715/715 - 6s - 8ms/step - loss: 4.7420e-04 - val_loss: 5.8555e-04
# Epoch 33/50
# 715/715 - 6s - 8ms/step - loss: 5.1269e-04 - val_loss: 5.2943e-04
# Epoch 34/50
# 715/715 - 6s - 8ms/step - loss: 4.2673e-04 - val_loss: 3.3239e-04
# Epoch 35/50
# 715/715 - 6s - 8ms/step - loss: 3.3555e-04 - val_loss: 2.0671e-04
# Epoch 36/50
# 715/715 - 6s - 8ms/step - loss: 2.9441e-04 - val_loss: 1.4906e-04
# Epoch 37/50
# 715/715 - 6s - 8ms/step - loss: 2.6260e-04 - val_loss: 1.4883e-04
# Epoch 38/50
# 715/715 - 6s - 8ms/step - loss: 2.3881e-04 - val_loss: 2.5421e-04
# Epoch 39/50
# 715/715 - 6s - 8ms/step - loss: 3.2279e-04 - val_loss: 7.6675e-04
# Epoch 40/50
# 715/715 - 6s - 8ms/step - loss: 8.3643e-04 - val_loss: 0.0013
# Epoch 41/50
# 715/715 - 6s - 8ms/step - loss: 7.6570e-04 - val_loss: 3.8543e-04
# Epoch 42/50
# 715/715 - 6s - 8ms/step - loss: 2.8951e-04 - val_loss: 1.2822e-04
# Epoch 43/50
# 715/715 - 6s - 8ms/step - loss: 3.2749e-04 - val_loss: 2.1048e-04
# Epoch 44/50
# 715/715 - 6s - 8ms/step - loss: 3.5205e-04 - val_loss: 2.8798e-04
# Epoch 45/50
# 715/715 - 6s - 8ms/step - loss: 2.7238e-04 - val_loss: 1.8151e-04
# Epoch 46/50
# 715/715 - 6s - 8ms/step - loss: 2.0386e-04 - val_loss: 1.0895e-04
# Epoch 47/50
# 715/715 - 6s - 8ms/step - loss: 1.9683e-04 - val_loss: 3.1392e-04
# Epoch 48/50
# 715/715 - 6s - 8ms/step - loss: 4.6861e-04 - val_loss: 0.0011
# Epoch 49/50
# 715/715 - 6s - 8ms/step - loss: 9.7391e-04 - val_loss: 9.8860e-04
# Epoch 50/50
# 715/715 - 6s - 8ms/step - loss: 5.1527e-04 - val_loss: 1.8673e-04
# 5133/5133 ━━━━━━━━━━━━━━━━━━━━ 6s 1ms/step
# Test RMSE: 0.014

# %%
e = np.round(sum(np.abs(inv_y[:]-inv_yhat[:]))/(sum(inv_y[:])*len(inv_y[:]))*100,2)
aa=[x for x in range(160000)]
plt.figure(figsize=(25,10)) 
plt.plot(aa, inv_y[:160000], marker='.', label="actual")
plt.plot(aa, inv_yhat[:160000], 'r', label="prediction with precision of {} %".format(e))
plt.ylabel(df.columns[0], size=15)
plt.xlabel('Time', size=15)
plt.legend(fontsize=15)
plt.show()

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

yhat_binary = np.where(inv_yhat >= threshold, 1, 0)
inv_y_binary = np.where(inv_y >= threshold, 1, 0)

accuracy = accuracy_score(inv_y_binary, yhat_binary)
precision = precision_score(inv_y_binary, yhat_binary)
recall = recall_score(inv_y_binary, yhat_binary)
f1 = f1_score(inv_y_binary, yhat_binary)

print('Accuracy: %.3f' % accuracy)
print('Precision: %.3f' % precision)
print('Recall: %.3f' % recall)
print('F1 Score: %.3f' % f1)
# Out:
# Accuracy: 0.998
# Precision: 1.000
# Recall: 0.998
# F1 Score: 0.999

# %%
model.save('lstm_model.h5')
# Out:
# WARNING: You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
